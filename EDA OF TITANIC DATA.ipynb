# %% [markdown]
# #EDA OF TITANIC DATA

# %%
# LOADING NECESSARY LIBRARIES 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
#loading dataset 
titanic_data=sns.load_dataset("titanic")

# %%
titanic_data.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#numbe of columns in titanic datasets
print(titanic_data.shape)
print(titanic_data.size)
# Out:
# (891, 15)
# 13365

# %% [markdown]
# number of columns are  15
# number of rows are 891
# number of data points are   13365

# %%
#name of columns -
titanic_data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# number of data in each columns that are not null
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# Number of data in each columns that are null.
titanic_data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.heatmap(titanic_data.isnull(),cmap='Blues',cbar=True)
# Out:
# <AxesSubplot:>

# %%
titanic_data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic_data.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic_data["age"].fillna(0,inplace=True)

# %%
titanic_data["deck"].fillna("C",inplace=True)

# %%
titanic_data["embark_town"].fillna("Cherbourg",inplace=True)
titanic_data["embarked"].fillna("S",inplace=True)

# %%
#correlation between every variables 
corr_titanic=titanic_data.corr()
corr_titanic
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481  0.010539 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.361353  0.083081  0.018443 -0.549500
# age         0.010539 -0.361353  1.000000 -0.184664 -0.048786  0.135516
# sibsp      -0.035322  0.083081 -0.184664  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.048786  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.135516  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.120022 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.030880 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.120022  0.030880
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(corr_titanic,annot= True ,square=True ,cmap='Blues',cbar=True,)
# Out:
# <AxesSubplot:>

# %%
# Analysis on survived columns:
print(titanic_data["survived"].value_counts())
print(sns.countplot("survived",data=titanic_data))
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64
# AxesSubplot(0.125,0.11;0.775x0.77)
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(titanic_data["survived"].value_counts().plot.pie(autopct="%1.1f%%"))
# Out:
# AxesSubplot(0.22375,0.11;0.5775x0.77)

# %%
#Analysis of age :
print(titanic_data["age"].value_counts())
print(sns.countplot("age",data=titanic_data))
# Out:
# 0.00     177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: age, Length: 89, dtype: int64
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
# Analysis on passenger class columns:
print(titanic_data["pclass"].value_counts())
print(sns.countplot("pclass",data=titanic_data))
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64
# AxesSubplot(0.125,0.11;0.775x0.77)
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(titanic_data["pclass"].value_counts().plot.pie(autopct="%1.1f%%"))
# Out:
# AxesSubplot(0.22375,0.11;0.5775x0.77)

# %%
# Analysis of sex:
print(titanic_data["sex"].value_counts())
print(sns.countplot("sex",data=titanic_data))
# Out:
# male      577
# female    314
# Name: sex, dtype: int64
# AxesSubplot(0.125,0.11;0.775x0.77)
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(titanic_data["sex"].value_counts().plot.pie(autopct="%1.1f%%"))
# Out:
# AxesSubplot(0.22375,0.11;0.5775x0.77)

# %%
# Analysis of fare:
print(titanic_data["fare"].value_counts())
print(sns.countplot("fare",data=titanic_data))
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: fare, Length: 248, dtype: int64
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
# Analysis of adult_male:
print(titanic_data["adult_male"].value_counts())
print(sns.countplot("adult_male",data=titanic_data))
# Out:
# True     537
# False    354
# Name: adult_male, dtype: int64
# AxesSubplot(0.125,0.11;0.775x0.77)
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(titanic_data["adult_male"].value_counts().plot.pie(autopct="%1.1f%%"))
# Out:
# AxesSubplot(0.22375,0.11;0.5775x0.77)

# %%
# Analysis of alone:
print(titanic_data["alone"].value_counts())
print(sns.countplot("alone",data=titanic_data))
# Out:
# True     537
# False    354
# Name: alone, dtype: int64
# AxesSubplot(0.125,0.11;0.775x0.77)
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(titanic_data["alone"].value_counts().plot.pie(autopct="%1.1f%%"))
# Out:
# AxesSubplot(0.22375,0.11;0.5775x0.77)

# %%
# Analysis of parch:
print(titanic_data["parch"].value_counts())
print(sns.countplot("parch",data=titanic_data))
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: parch, dtype: int64
# AxesSubplot(0.125,0.11;0.775x0.77)
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(titanic_data["parch"].value_counts().plot.pie(autopct="%1.1f%%"))
# Out:
# AxesSubplot(0.22375,0.11;0.5775x0.77)

# %%
#bivariate analysis of variables 
print(sns.countplot("survived",data=titanic_data,hue="pclass"))
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(sns.countplot("survived",data=titanic_data,hue="sex"))
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(sns.countplot("sex",data=titanic_data,hue="pclass"))
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
print(sns.countplot("survived",data=titanic_data,hue="adult_male"))
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# AxesSubplot(0.125,0.11;0.775x0.77)
